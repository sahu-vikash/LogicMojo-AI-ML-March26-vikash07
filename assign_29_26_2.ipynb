# %% [markdown]
# Customer Segmentation Engine

# %%
customers = [
    {"id": 1, "age": 25, "income": 50000, "spend": 20000},
    {"id": 2, "age": 45, "income": 120000, "spend": 80000},
    {"id": 3, "age": 35, "income": 70000, "spend": 30000}
]

def segment_customer(customers):
    segemented_custmer = []
    for customer in customers:
        print
        if customer['spend']/customer['income'] > 0.6:
             segemented_custmer.append({"id":customer['id'],"segement":"High Value"})
        elif customer['spend']/customer['income'] >= 0.3 and customer['spend']/customer['income'] <=0.6:
            segemented_custmer.append({"id":customer['id'],"segement":"Mid Value"})
        else:
            segemented_custmer.append({"id":customer['id'],"segement":"Low Value"})

    return segemented_custmer

print(segment_customer(customers))
# Out:
# [{'id': 1, 'segement': 'Mid Value'}, {'id': 2, 'segement': 'High Value'}, {'id': 3, 'segement': 'Mid Value'}]

# %% [markdown]
# Text Cleaning Pipeline

# %%
texts = [
    "Hello!!! How are you???",
    "This is    AI     class.",
    "Python@@@is###great"
]
def clean_text(text):
