# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from scipy import integrate
import math

# %% [markdown]
# **20**

# %% [markdown]
# ***In optimization landscapes of neural networks, the concepts of local minima and global minima are extremely important. Which statement correctly differentiates them?***
#
# - [ ] A. Local minsima is always the absolute smallest value everywhere
#
# - [ ] B. Global minima exists only for convex functions
#
# - [x] C. Local minima is smallest in a nearby region, while global minima is smallest overall
#
# - [ ] D. Local minima and global minima are always identical

# %% [markdown]
# ### Explanation
#
# As part of the graph of Gradient Descent optimization:
# * **Blue Line**: Represents the loss function.
# * **Scattered Red Dots**: Represent the gradient descent steps as it moves from $-1$ towards $0$, which is a local minimum.
#
# Looking further at the graph, more minima points are available:
#
# * **A.** It classifies that a local minimum is not the absolute smallest value. **[False]**
# * **B.** If we check the graph, the smallest minimum is around $-8$ (global minimum). Since the available graph is not convex, it makes the statement. **[False]**
# * **C.** Multiple minimum points are available and the first minimum is the smallest in the nearby region, while the global minimum is the absolute smallest (around $-8$). **[True]**
# * **D.** Only in the case of a convex function will the local and global minima be identical. Because this graph is not convex, they are different. **[False]**

# %%
#function declaration
def f(x):
    return x**4 - 3*x**3

#first differentiation
def df(x):
    return 4*x**3 - 9*x**2


#define a gradient descent for first local minima
starting_point=-1
learning_rate = 0.01
steps = 50

#initializing list to add all the variation point
starting_point_cont = [starting_point]

for i in range(steps):
    #Gradient descent update x = x - learning_rate * f'(x)
    starting_point = starting_point - learning_rate * df(starting_point)
    starting_point_cont.append(starting_point)


#define a gradient descent for Global absolute minima
starting_point_second_minima=1

#initializing list to add all the variation point
starting_point_cont_2 = [starting_point_second_minima]

for i in range(steps):
    #Gradient descent update x = x - learning_rate * f'(x)
    starting_point_second_minima = starting_point_second_minima - learning_rate * df(starting_point_second_minima)
    starting_point_cont_2.append(starting_point_second_minima)

x_range = np.linspace(-2,3, 100)
y_range = f(x_range)

plt.plot(x_range, y_range,label = 'loss function')
plt.scatter(starting_point_cont, [f(step) for step in starting_point_cont], color='red', label='Gradient descent steps')
plt.scatter(starting_point_cont_2, [f(step) for step in starting_point_cont_2], color='skyblue', label='Gradient descent steps')
plt.title("Gradient Descent optimization")
plt.xlabel("x")
plt.ylabel("loss function f(x)")

# Arrow for local minima
plt.annotate('1 Local Minima',
             xy=(starting_point_cont[len(starting_point_cont)-1], f(starting_point_cont[len(starting_point_cont)-1])),
             xytext=(starting_point_cont[len(starting_point_cont)-1] - 0.5, f(starting_point_cont[len(starting_point_cont)-1]) + 8),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=6))

plt.annotate('Global absolute minima',
             xy=(starting_point_cont_2[len(starting_point_cont_2)-1], f(starting_point_cont_2[len(starting_point_cont_2)-1])),
             xytext=(starting_point_cont_2[len(starting_point_cont_2)-1] - 0.5, f(starting_point_cont_2[len(starting_point_cont_2)-1]) + 8),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=6))

plt.legend()
plt.show()

# %%
**19**

# %% [markdown]
# ***Trigonometric derivatives are commonly used in optimization and signal processing. Which of the following correctly represents the derivative of:***
#
# f(x) = cos(x)
#
# - [ ] A. sin(x)
#
# - [x] B. -sin(x)
#
# - [ ] C. -cos(x)
#
# - [ ] D. tan(x)

# %%
x = sp.Symbol('x')
F = sp.cos(x)
f_x=sp.diff(F,x)
print(f" Derivative of f(x) = cos(x) is {f_x}")
# Out:
#  Derivative of f(x) = cos(x) is -sin(x)

# %% [markdown]
# **17**

# %% [markdown]
# ***In Linear Algebra, eigenvectors are heavily used in PCA, recommendation systems, and computer vision applications. What is the most accurate interpretation of an eigenvector?***
#
# - [ ] A. A vector that completely disappears after transformation
#
# - [x] B. A vector whose direction remains unchanged after transformation
#
# - [ ] C. A random vector generated from covariance matrices
#
# - [ ] D. A vector perpendicular to every other vector

# %%
A = np.array([[2,1],[1,2]])

#Finding eigen value and eigen vector
eig_val, eig_vec = np.linalg.eig(A)

print(f"eigen values {eig_val}")
print(f"eigen vector {eig_vec}")

#extract first eigen value and vector
first_vector = eig_vec[:,0]
first_value  = eig_val[0]

second_vector = eig_vec[:,1]
second_value  = eig_val[1]

#Matrix transformation 1
trns_matrix = A @ first_vector

#Matrix transformation 2
trns_matrix_1 = A @ second_vector

x_val = np.linspace(-3,3,10)
plt.plot(x_val, ((first_vector[1]/first_vector[0])*x_val), color='cyan', alpha=0.2, label='Direction Line first vector')
plt.plot(x_val, ((second_vector[1]/second_vector[0])*x_val), color='cyan', alpha=0.2, label='Direction Line second vector')
plt.quiver(0, 0, first_vector[0], first_vector[1], angles='xy', scale_units='xy', scale=1,
           color='blue', width=0.01, label=f'Original v1 {first_vector.round(2)}')

plt.quiver(0, 0, trns_matrix[0], trns_matrix[1], angles='xy', scale_units='xy', scale=1,
           color='blue', width=0.006, label=f'Transformed matrix 1 {trns_matrix.round(2)}')

plt.quiver(0, 0, second_vector[0], second_vector[1], angles='xy', scale_units='xy', scale=1,
           color='red', width=0.01, label=f'Original v2 {second_vector.round(2)}')

plt.quiver(0, 0, trns_matrix_1[0], trns_matrix_1[1], angles='xy', scale_units='xy', scale=1,
           color='red', width=0.01, label=f'Transformed matrix 2 {trns_matrix_1.round(2)}')

plt.gca().set_aspect('equal', adjustable='box')

plt.xlim([-3, 3])
plt.ylim([-3, 3])
plt.grid(True, ls=':')
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'Eigenvector Direction Stays on the Same Line (λ ≈ {first_value:.2f})')
#plt.legend(loc='upper right')
plt.show()
# Out:
# eigen values [3. 1.]
# eigen vector [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %% [markdown]
# 16

# %% [markdown]
# ***Evaluate the following definite integral frequently used in probability and area-under-curve calculations:
# Integral from 0 to 1 of x^2 dx***
#
# - [ ] A. 1/2
#
# - [x] B. 1/3
#
# - [ ] C. 1
#
# - [ ] D. 2
#
# __As mentioned below the area under the curve for definitive integral frequency__

# %%
#defining function
def f(x):
    return x**2

result, error = integrate.quad(f,0,1)
print(f"definite integral {result}")
print(f"Error {error}")

#Generating area under the curve for above result
x_val = np.linspace(-0.2, 1.5, 100)
y_val = f(x_val)

#for filling (as have limit) area under the curve starting 0 end 1.
x_fill = np.linspace(0,1,100)
y_fill = f(x_fill)

plt.plot(x_val, y_val, color='blue', linewidth=2, label='$f(x) = x^2$')
plt.fill_between(x_fill, y_fill, color='lightblue', alpha=0.5,
                 label=f'Area = {result:.3f}')

#setting vertical boundry as area start from 0 and end with 1.
plt.vlines([0, 1], 0, [f(0), f(1)],
           color='red', linestyle='--', alpha=0.7)

plt.xlim([-0.2, 1.4])
plt.ylim([0, 1.4])
plt.grid(True, ls=':', alpha=0.6)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('definite integral frequently')
plt.legend(loc='upper left')
plt.show()
# Out:
# definite integral 0.33333333333333337
# Error 3.700743415417189e-15

# %% [markdown]
# 14. ***Consider the multivariable function:***
#
# ***f(x, y) = x^2 + y^2***
#
# ***What is the correct gradient vector for this function?***
#
# - [ ] A. (x, y)
#
# - [x] B. (2x, 2y)
#
# - [ ] C. (x^2, y^2)
#
# - [ ] D. (2, 2)

# %%
x,y = sp.symbols('x y')

F = x**2 + y**2

f_x = sp.diff(F,x)
f_y = sp.diff(F,y)
print(f"gradient vector :: ({f_x} , {f_y})")
# Out:
# gradient vector :: (2*x , 2*y)

# %% [markdown]
# **13**

# %% [markdown]
# ***In probability theory, two events are called mutually exclusive when they cannot occur simultaneously. Which mathematical expression correctly represents mutually exclusive events?***
#
# - [ ] A. P(A ∩ B) = 1
#
# - [x] B. P(A ∩ B) = 0
#
# - [ ] C. P(A ∪ B) = 0
#
# - [ ] D. P(A) = P(B)

# %% [markdown]
# 12. ***While solving systems of linear equations in AI/ML applications, the determinant of a matrix is often checked before inversion. Why is the determinant important?***
#
# - [ ] A. It measures feature scaling efficiency
#
# - [x] B. It determines whether a matrix is invertible or singular
#
# - [ ] C. It calculates probability distributions
#
# - [ ] D. It measures neural network convergence speed
#
# Explaination : Why determinant of a matrix is often checked before inversion
# if determinant of matrix is 0 then inverse can not be identified.
# As inverse of A = 1/|A|. adj(A) if det is 0 then it will become 1/0 that breaks the inversion.

# %%
matrix2_2 = [[2,4],[1,2]]

print(matrix2_2)

det_2_2 = np.linalg.det(matrix2_2)

#as it's is linear dependent thus det=0
print(det_2_2)

try:
    inv2_2=np.linalg.inv(matrix2_2)
    print(inv2_2)
except Exception as err:
    print(err)

# Result shown det as zero has no multiplication inverse as output can seen as singular matrix as error output from trace
# Out:
# [[2, 4], [1, 2]]
# 0.0
# Singular matrix

# %%
**1**

# %% [markdown]
# A machine learning engineer is analyzing the function:
# f(x) = x^3 * sin(x)
#
# for optimization behavior and gradient flow. While calculating the derivative using differentiation techniques, which of the following expressions correctly represents f'(x)?
#
# - [ ] A. 3x^2sin(x)
#
# - [ ] B. x^3cos(x)
#
# - [x] C. 3x^2sin(x) + x^3cos(x)
#
# - [ ] D. 3x^2cos(x) + x^3sin(x)

# %%
#As we know f(x) = UV = U'V + UV'
x = sp.Symbol('x')

f_dash_x = sp.diff(x**3,x) * sp.sin(x) + x**3 * sp.diff(sp.sin(x),x)
print(f_dash_x)
# Out:
# x**3*cos(x) + 3*x**2*sin(x)

# %%
**2**

# %% [markdown]
# In deep learning and optimization algorithms, Gradient Descent is one of the most widely used optimization techniques. What is the primary objective of using Gradient Descent during model training?
#
# - [ ] A. To continuously increase the dimensionality of training data for better learning
#
# - [x] B. To minimize the loss function by updating parameters in the negative gradient direction
#
# - [ ] C. To randomly initialize weights for avoiding overfitting problems
#
# - [ ] D. To convert non-linear functions into linear equations automatically

# %% [markdown]
# **Please ref program 20 solution for gredient descent steps as part of the graph by updating parameter in negative direction**

# %% [markdown]
# **3**

# %% [markdown]
# Consider the following mathematical functions frequently used in AI/ML:
#
# log(x), x^2, x, e^x
#
# As the value of x becomes extremely large, which function grows at the fastest rate and dominates all others?
#
# - [ ] A. log(x)
#
# - [ ] B. x^2
#
# - [ ] C. x
#
# - [x] D. e^x
#
# Note: Hirearchy of mathematical function **log(x) < x < x^2 < e^x**

# %%
# Generate 20 points between 1 and 5
x = np.linspace(1, 5, 20)

# Calculate the function values
y_log = np.log(x)
y_linear = x
y_square = x**2
y_exp = np.exp(x)

fig, ax1 = plt.subplots(figsize=(14, 6))

# Linear Scale (Shows exponential explosion)
ax1.plot(x, y_log, label='log(x)', color='blue', linewidth=0.5)
ax1.plot(x, y_linear, label='x', color='yellow', linewidth=1)
ax1.plot(x, y_square, label='x^2', color='green', linewidth=2)
ax1.plot(x, y_exp, label='e^x', color='red', linewidth=2.5)

ax1.set_title('Linear Scale: e^x Dominates Completely', fontsize=12)
ax1.set_xlabel('x', fontsize=10)
ax1.set_ylabel('f(x)', fontsize=10)
ax1.grid(True, linestyle='-', alpha=0.5)
ax1.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# **4**

# %% [markdown]
# In machine learning cost functions and probabilistic models, natural logarithms are heavily used. If:
#
# f(x) = ln(x)
#
# then which of the following correctly represents the derivative of f(x)?
#
# - [x] A. 1/x
#
# - [ ] B. x
#
# - [ ] C. e^x
#
# - [ ] D. ln(x)

# %% [markdown]
# **5**

# %% [markdown]
# In multivariable calculus, the Gradient Vector plays a critical role
# in optimization and neural network training. Geometrically, what does the
# gradient vector of a function represent?
#
# - [x] A. The direction in which the function decreases most rapidly
#
# - [ ] B. The direction of steepest ascent where the function increases fastest
#
# - [ ] C. The average curvature of the function surface
#
# - [ ] D. A vector perpendicular to all tangent planes

# %% [markdown]
# **6**

# %% [markdown]
# During backpropagation in neural networks, composite functions are
# differentiated repeatedly. Which differentiation rule is specifically used
# for differentiating composite functions such as:
#
# f(g(x))
#
# - [ ] A. Product Rule
#
# - [ ] B. Quotient Rule
#
# - [x] C. Chain Rule
#
# - [ ] D. Power Rule

# %% [markdown]
# **7**

# %% [markdown]
# In optimization theory, convex functions are extremely important because
# they simplify finding global minima. Which mathematical condition generally
# indicates that a function is convex?
#
# - [ ] A. The first derivative is always equal to zero
#
# - [x] B. The second derivative remains positive
#
# - [ ] C. The gradient vector becomes undefined
#
# - [ ] D. The determinant of Hessian becomes zero

# %% [markdown]
# **8**

# %% [markdown]
# The exponential function appears frequently in Machine Learning,
# especially in Softmax and Logistic Regression. Which of the following
# correctly represents the derivative of:
#
# f(x) = e^x
#
# - [ ] A. xe^(x-1)
#
# - [ ] B. ln(x)
#
# - [x] C. e^x
#
# - [ ] D. x^x

# %% [markdown]
# **9**

# %% [markdown]
# In second-order optimization techniques such as Newton’s Method,
# which matrix contains all second-order partial derivatives of a multivariable function?
#
# - [ ] A. Jacobian Matrix
#
# - [ ] B. Identity Matrix
#
# - [x] C. Hessian Matrix
#
# - [ ] D. Orthogonal Matrix

# %% [markdown]
# **10**

# %% [markdown]
# Two vectors are said to be orthogonal when the angle between them is 90 degrees.
# For such vectors, what will always be the value of their dot product?
#
# - [ ] A. 1
#
# - [ ] B. -1
#
# - [x] C. 0
#
# - [ ] D. Infinity

# %% [markdown]
# **11**

# %% [markdown]
# Principal Component Analysis (PCA) is one of the most important dimensionality
# reduction techniques in Machine Learning. Which matrix decomposition technique
# is most closely associated with PCA implementations?
#
# - [ ] A. LU Decomposition
#
# - [ ] B. QR Decomposition
#
# - [x] C. Singular Value Decomposition (SVD)
#
# - [ ] D. Cholesky Decomposition

# %% [markdown]
# **12**

# %% [markdown]
# While solving systems of linear equations in AI/ML applications,
# the determinant of a matrix is often checked before inversion.
# Why is the determinant important?
#
# - [ ] A. It measures feature scaling efficiency
#
# - [x] B. It determines whether a matrix is invertible or singular
#
# - [ ] C. It calculates probability distributions
#
# - [ ] D. It measures neural network convergence speed

# %% [markdown]
# **15**

# %% [markdown]
# In very deep neural networks, gradients sometimes become extremely small
# during backpropagation, causing learning to slow down significantly.
# What is this problem commonly called?
#
# - [ ] A. Overfitting Problem
#
# - [x] B. Vanishing Gradient Problem
#
# - [ ] C. Covariance Shift
#
# - [ ] D. Underfitting Error

# %% [markdown]
# **18**

# %% [markdown]
# Bayesian Machine Learning relies heavily on probabilistic reasoning.
# Which interpretation of probability treats probability as a degree of belief
# based on available evidence?
#
# - [ ] A. Classical Interpretation
#
# - [ ] B. Frequentist Interpretation
#
# - [x] C. Bayesian Interpretation
#
# - [ ] D. Deterministic Interpretation
